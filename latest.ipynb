# %%
from models import *

# %%
AREA = 80
VOLUME = 5.2
CONFIG_FILE = './config.json'

# %%
simulation = SimulationEnvironment(AREA, VOLUME, CONFIG_FILE)
simulation.collector_area
simulation.storage_tank_volume
# Out:
# 5.2

# %%
simulation.plot_water_consumption()

# %%
simulation.simulate_single_day(month=4)
# Out:
# AUXILIARY ENERGY 473.463 MJ
# TOTAL_ENERGY 0.000 MJ
# THE SOLAR FRACTION IS: 1.000
# DatetimeIndex(['2006-04-15 00:00:00', '2006-04-15 01:00:00',
#                '2006-04-15 02:00:00', '2006-04-15 03:00:00',
#                '2006-04-15 04:00:00', '2006-04-15 05:00:00',
#                '2006-04-15 06:00:00', '2006-04-15 07:00:00',
#                '2006-04-15 08:00:00', '2006-04-15 09:00:00',
#                '2006-04-15 10:00:00', '2006-04-15 11:00:00',
#                '2006-04-15 12:00:00', '2006-04-15 13:00:00',
#                '2006-04-15 14:00:00', '2006-04-15 15:00:00',
#                '2006-04-15 16:00:00', '2006-04-15 17:00:00',
#                '2006-04-15 18:00:00', '2006-04-15 19:00:00',
#                '2006-04-15 20:00:00', '2006-04-15 21:00:00',
#                '2006-04-15 22:00:00', '2006-04-15 23:00:00'],
#               dtype='datetime64[ns]', name='time', freq=None)
# DATE_TIME_LEN 288
# STORAGE_WATER_TEMPERATURE_LEN 288

# %%
simulation.simulate_month(month=1)
# Out:
# Month Simulation _ start_date_time 2006-01-01 00:00:00
# Month Simulation _ days in month 31
# Month Simulation _ simulation period 2678400
# AUXILIARY ENERGY 20.090 GJ
# TOTAL_ENERGY 2.197 GJ
# THE SOLAR FRACTION IS: 0.891
# DatetimeIndex(['2006-01-01 05:00:00', '2006-01-01 06:00:00',
#                '2006-01-01 07:00:00', '2006-01-01 08:00:00',
#                '2006-01-01 09:00:00', '2006-01-01 10:00:00',
#                '2006-01-01 11:00:00', '2006-01-01 12:00:00',
#                '2006-01-01 13:00:00', '2006-01-01 14:00:00',
#                ...
#                '2006-01-31 14:00:00', '2006-01-31 15:00:00',
#                '2006-01-31 16:00:00', '2006-01-31 17:00:00',
#                '2006-01-31 18:00:00', '2006-01-31 19:00:00',
#                '2006-01-31 20:00:00', '2006-01-31 21:00:00',
#                '2006-01-31 22:00:00', '2006-01-31 23:00:00'],
#               dtype='datetime64[ns]', name='time', length=739, freq=None)

# %%
simulation.simulate_entire_year()
# Out:
# AUXILIARY ENERGY 218.217 GJ
# TOTAL_ENERGY 56.994 GJ
# THE SOLAR FRACTION IS: 0.739
# DatetimeIndex(['2006-01-01 05:00:00', '2006-01-01 06:00:00',
#                '2006-01-01 07:00:00', '2006-01-01 08:00:00',
#                '2006-01-01 09:00:00', '2006-01-01 10:00:00',
#                '2006-01-01 11:00:00', '2006-01-01 12:00:00',
#                '2006-01-01 13:00:00', '2006-01-01 14:00:00',
#                ...
#                '2006-12-31 14:00:00', '2006-12-31 15:00:00',
#                '2006-12-31 16:00:00', '2006-12-31 17:00:00',
#                '2006-12-31 18:00:00', '2006-12-31 19:00:00',
#                '2006-12-31 20:00:00', '2006-12-31 21:00:00',
#                '2006-12-31 22:00:00', '2006-12-31 23:00:00'],
#               dtype='datetime64[ns]', name='time', length=8755, freq=None)

# %%
simulation.collector_area = 140
simulation.storage_tank_volume = 5
simulation.simulate_single_day(month=4)
# Out:
# AUXILIARY ENERGY 473.463 MJ
# TOTAL_ENERGY 0.000 MJ
# THE SOLAR FRACTION IS: 1.000
# DatetimeIndex(['2006-04-15 00:00:00', '2006-04-15 01:00:00',
#                '2006-04-15 02:00:00', '2006-04-15 03:00:00',
#                '2006-04-15 04:00:00', '2006-04-15 05:00:00',
#                '2006-04-15 06:00:00', '2006-04-15 07:00:00',
#                '2006-04-15 08:00:00', '2006-04-15 09:00:00',
#                '2006-04-15 10:00:00', '2006-04-15 11:00:00',
#                '2006-04-15 12:00:00', '2006-04-15 13:00:00',
#                '2006-04-15 14:00:00', '2006-04-15 15:00:00',
#                '2006-04-15 16:00:00', '2006-04-15 17:00:00',
#                '2006-04-15 18:00:00', '2006-04-15 19:00:00',
#                '2006-04-15 20:00:00', '2006-04-15 21:00:00',
#                '2006-04-15 22:00:00', '2006-04-15 23:00:00'],
#               dtype='datetime64[ns]', name='time', freq=None)
# DATE_TIME_LEN 288
# STORAGE_WATER_TEMPERATURE_LEN 288

# %%
simulation.simulate_month(10)
simulation.simulation_params
# Out:
# Month Simulation _ start_date_time 2006-10-01 00:00:00
# Month Simulation _ days in month 31
# Month Simulation _ simulation period 2678400
# AUXILIARY ENERGY 19.140 GJ
# TOTAL_ENERGY 1.373 GJ
# THE SOLAR FRACTION IS: 0.928
# DatetimeIndex(['2006-01-01 05:00:00', '2006-01-01 06:00:00',
#                '2006-01-01 07:00:00', '2006-01-01 08:00:00',
#                '2006-01-01 09:00:00', '2006-01-01 10:00:00',
#                '2006-01-01 11:00:00', '2006-01-01 12:00:00',
#                '2006-01-01 13:00:00', '2006-01-01 14:00:00',
#                ...
#                '2006-01-31 14:00:00', '2006-01-31 15:00:00',
#                '2006-01-31 16:00:00', '2006-01-31 17:00:00',
#                '2006-01-31 18:00:00', '2006-01-31 19:00:00',
#                '2006-01-31 20:00:00', '2006-01-31 21:00:00',
#                '2006-01-31 22:00:00', '2006-01-31 23:00:00'],
#               dtype='datetime64[ns]', name='time', length=739, freq=None)
# SimulationParameters(A_c=140, V_st=5, F_r_tao_alpha=0.675, F_r_U_l=5.656, m_l_dot=0.1559375, C_p=4180, T_l=60, rho=998, consumption_pattern=[{'start': '06:00', 'end': '08:00'}, {'start': '10:00', 'end': '11:00'}, {'start': '12:00', 'end': '13:00'}, {'start': '14:00', 'end': '18:00'}], U_st=0.19999520011519725, A_st=16.61319595394682, environment_conditions=                     poa_global  solar_elevation  temp_air  wind_speed  Int
# time
# 2006-01-01 05:00:00        0.00             0.00     13.82        4.03    0
# 2006-01-01 06:00:00        0.00             0.00     14.85        3.88    0
# 2006-01-01 07:00:00        0.00             1.33     15.88        3.72    1
# 2006-01-01 08:00:00      254.01            13.93     16.91        3.57    0
# 2006-01-01 09:00:00      532.72            25.69     19.91        3.94    0
# ...                         ...              ...       ...         ...  ...
# 2007-01-01 00:00:00        0.00             0.00     19.29        2.57    0
# 2007-01-01 01:00:00        0.00             0.00     18.58        2.50    0
# 2007-01-01 02:00:00        0.00             0.00     17.86        2.43    0
# 2007-01-01 03:00:00        0.00             0.00     17.86        2.43    0
# 2007-01-01 04:00:00        0.00             0.00     17.86        2.43    0
#
# [8760 rows x 5 columns])

# %%
simulation.simulate_entire_year()
# Out:
# AUXILIARY ENERGY 218.217 GJ
# TOTAL_ENERGY 27.673 GJ
# THE SOLAR FRACTION IS: 0.873
# DatetimeIndex(['2006-01-01 05:00:00', '2006-01-01 06:00:00',
#                '2006-01-01 07:00:00', '2006-01-01 08:00:00',
#                '2006-01-01 09:00:00', '2006-01-01 10:00:00',
#                '2006-01-01 11:00:00', '2006-01-01 12:00:00',
#                '2006-01-01 13:00:00', '2006-01-01 14:00:00',
#                ...
#                '2006-12-31 14:00:00', '2006-12-31 15:00:00',
#                '2006-12-31 16:00:00', '2006-12-31 17:00:00',
#                '2006-12-31 18:00:00', '2006-12-31 19:00:00',
#                '2006-12-31 20:00:00', '2006-12-31 21:00:00',
#                '2006-12-31 22:00:00', '2006-12-31 23:00:00'],
#               dtype='datetime64[ns]', name='time', length=8755, freq=None)
