# %%
from models import *

# %%
AREA = 80
VOLUME = 5.2
CONFIG_FILE = './config.json'

# %%
simulation = SimulationEnvironment(AREA, VOLUME, CONFIG_FILE)
simulation.collector_area
simulation.storage_tank_volume
# Out:
# 5.2

# %%
# simulation.foo()

# %%
simulation.environment_conditions
# print(type(simulation.environment_conditions))
# Out:
#                      poa_global  solar_elevation  temp_air  wind_speed  Int
# time
# 2006-01-01 05:00:00        0.00             0.00     13.82        4.03    0
# 2006-01-01 06:00:00        0.00             0.00     14.85        3.88    0
# 2006-01-01 07:00:00        0.00             1.33     15.88        3.72    1
# 2006-01-01 08:00:00      254.01            13.93     16.91        3.57    0
# 2006-01-01 09:00:00      532.72            25.69     19.91        3.94    0
# ...                         ...              ...       ...         ...  ...
# 2007-01-01 00:00:00        0.00             0.00     19.29        2.57    0
# 2007-01-01 01:00:00        0.00             0.00     18.58        2.50    0
# 2007-01-01 02:00:00        0.00             0.00     17.86        2.43    0
# 2007-01-01 03:00:00        0.00             0.00     17.86        2.43    0
# 2007-01-01 04:00:00        0.00             0.00     17.86        2.43    0
#
# [8760 rows x 5 columns]

# %%
simulation.simulate_single_day(month=4)
# Out:
# CRRTIME 00:00:00
# CRRTIME 00:05:00
# CRRTIME 00:10:00
# CRRTIME 00:15:00
# CRRTIME 00:20:00
# CRRTIME 00:25:00
# CRRTIME 00:30:00
# CRRTIME 00:35:00
# CRRTIME 00:40:00
# CRRTIME 00:45:00
# CRRTIME 00:50:00
# CRRTIME 00:55:00
# CRRTIME 01:00:00
# CRRTIME 01:05:00
# CRRTIME 01:10:00
# CRRTIME 01:15:00
# CRRTIME 01:20:00
# CRRTIME 01:25:00
# CRRTIME 01:30:00
# CRRTIME 01:35:00
# CRRTIME 01:40:00
# CRRTIME 01:45:00
# CRRTIME 01:50:00
# CRRTIME 01:55:00
# CRRTIME 02:00:00
# CRRTIME 02:05:00
# CRRTIME 02:10:00
# CRRTIME 02:15:00
# CRRTIME 02:20:00
# CRRTIME 02:25:00
# CRRTIME 02:30:00
# CRRTIME 02:35:00
# CRRTIME 02:40:00
# CRRTIME 02:45:00
# CRRTIME 02:50:00
# CRRTIME 02:55:00
# CRRTIME 03:00:00
# CRRTIME 03:05:00
# CRRTIME 03:10:00
# CRRTIME 03:15:00
# CRRTIME 03:20:00
# CRRTIME 03:25:00
# CRRTIME 03:30:00
# CRRTIME 03:35:00
# CRRTIME 03:40:00
# CRRTIME 03:45:00
# CRRTIME 03:50:00
# CRRTIME 03:55:00
# CRRTIME 04:00:00
# CRRTIME 04:05:00
# CRRTIME 04:10:00
# CRRTIME 04:15:00
# ...

# %%
simulation.simulate_month(month=1)
# Out:
# Month Simulation _ start_date_time 2006-01-01 00:00:00
# Month Simulation _ days in month 31
00
# ...

# %%
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import pandas as pd

# Assuming df is your dataframe
def plot_poa_global(df, month=None, day=None):
    plt.figure(figsize=(12, 6))

    # Plot for a specific day of a specific month
    if month is not None and day is not None:
        daily_df = df.loc[df.index.to_series().dt.month == month]
        daily_df = daily_df.loc[daily_df.index.to_series().dt.day == day]
        plt.plot(daily_df.index, daily_df['poa_global'])
        plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%H:%M'))
        plt.title(f'POA Global for {day}-{month}')

    # Plot for all days in a specific month
    elif month is not None:
        monthly_df = df.loc[df.index.to_series().dt.month == month]
        plt.plot(monthly_df.index, monthly_df['poa_global'])
        plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%d'))
        plt.title(f'POA Global for Month {month}')

    # Plot for the entire year with month on the x-axis
    else:
        plt.plot(df.index, df['poa_global'])
        plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%b'))
        plt.title('POA Global for the Entire Year')

    # Common plot settings
    plt.xlabel('Time')
    plt.ylabel('POA Global')
    plt.grid(True)
    plt.legend(['POA Global'])
    plt.tight_layout()
    plt.show()

# Example usage:
# plot_poa_global(df, month=1, day=1) # For January 1st
# plot_poa_global(df, month=1) # For January
# plot_poa_global(df) # For the entire year

# %%
plot_poa_global(simulation.environment_conditions)

# %%
simulation.collector_area = 140
simulation.storage_tank_volume = 5
simulation.simulate_single_day(month=4)
# Out:
# CRRTIME 00:00:00
# CRRTIME 00:05:00
# CRRTIME 00:10:00
# CRRTIME 00:15:00
# CRRTIME 00:20:00
# CRRTIME 00:25:00
# CRRTIME 00:30:00
# CRRTIME 00:35:00
# CRRTIME 00:40:00
# CRRTIME 00:45:00
# CRRTIME 00:50:00
# CRRTIME 00:55:00
# CRRTIME 01:00:00
# CRRTIME 01:05:00
# CRRTIME 01:10:00
# CRRTIME 01:15:00
# CRRTIME 01:20:00
# CRRTIME 01:25:00
# CRRTIME 01:30:00
# CRRTIME 01:35:00
# CRRTIME 01:40:00
# CRRTIME 01:45:00
# CRRTIME 01:50:00
# CRRTIME 01:55:00
# CRRTIME 02:00:00
# CRRTIME 02:05:00
# CRRTIME 02:10:00
# CRRTIME 02:15:00
# CRRTIME 02:20:00
# CRRTIME 02:25:00
# CRRTIME 02:30:00
# CRRTIME 02:35:00
# CRRTIME 02:40:00
# CRRTIME 02:45:00
# CRRTIME 02:50:00
# CRRTIME 02:55:00
# CRRTIME 03:00:00
# CRRTIME 03:05:00
# CRRTIME 03:10:00
# CRRTIME 03:15:00
# CRRTIME 03:20:00
# CRRTIME 03:25:00
# CRRTIME 03:30:00
# CRRTIME 03:35:00
# CRRTIME 03:40:00
# CRRTIME 03:45:00
# CRRTIME 03:50:00
# CRRTIME 03:55:00
# CRRTIME 04:00:00
# CRRTIME 04:05:00
# CRRTIME 04:10:00
# CRRTIME 04:15:00
# ...

# %%
simulation.simulate_month(10)
simulation.simulation_params
# Out:
# Month Simulation _ start_date_time 2006-10-01 00:00:00
# Month Simulation _ days in month 31
