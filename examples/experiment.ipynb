# %%
import os
import os.path as path
import sys

EXAMPLE_DIR = path.abspath("")
GIT_DIR = path.split(EXAMPLE_DIR)[0]
SRC_DIR = path.join(GIT_DIR, "src")
sys.path.append(SRC_DIR)
from models import *

# %%
AREA = 90
VOLUME = 5
CONFIG_FILE = f'{EXAMPLE_DIR}/config.json'

# %%
simulation = SimulationEnvironment(AREA, VOLUME, CONFIG_FILE)
simulation.collector_area
simulation.storage_tank_volume
# Out:
# 5

# %%
simulation.simulate_single_day()
# Out:
# Total energy consumed: 473.463 MJ
# Auxiliary energy consumed: 0.000 MJ
# The solar fraction (F) is: 1.000

# %%
simulation.feaasible_design_space()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 simulation.feaasible_design_space()
#
# AttributeError: 'SimulationEnvironment' object has no attribute 'feaasible_design_space'
